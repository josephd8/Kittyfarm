# %%
import logging
import os
import re
import argparse
import multiprocessing
import glob
import boto3
import yaml
import pandas as pd
import json
import sqlalchemy
from sqlalchemy.orm import sessionmaker

import sys
sys.path.append("..")
import src.helpers.helpers as h

# %%
def connect_s3(access_id, access_key):
    
    s3 = boto3.resource('s3',
                    aws_access_key_id=access_id,
                    aws_secret_access_key=access_key)
    
    return s3

# %%
def get_s3_file_names(s3, s3_bucket_path):
    """Get all file names in an s3 bucket 

    Args:
        s3_bucket_path (str): S3 path to bucket containing all files to list (Ex: `s3://jdc-nu`)

    Returns: List of all S3 file locations

    """

    # parse s3 path for bucket name and prefix
    regex = r"s3://([\w._-]+)"
    m = re.match(regex, s3_bucket_path)
    s3bucket_name = m.group(1) 

    # Get s3 bucket handle
    s3bucket = s3.Bucket(s3bucket_name)

    # Get all file names in the `s3bucket`
    files = []
    for object in s3bucket.objects.all():
        file = object.key
        files.append(file)

    return files

# %%
files = get_s3_file_names("s3://jdc-nu",os.environ["AWS_ACCESS_ID"],os.environ["AWS_ACCESS_KEY"])

# %%
def set_kitties(file, s3, )

# %%
def load_kitty_json(file, s3, bucket = "jdc-nu"):
    
    obj = s3.Object(bucket,file)
    file_content = obj.get()['Body'].read().decode('utf-8')
    json_content = json.loads(file_content)
    
    return json_content

# %%
# test = [load_kitty_json(file, s3, bucket = "jdc-nu") for file in files]
# Out:
# KeyboardInterrupt

# %%
out = load_kitty_json(files[0], s3)

# %%
ind = 9999
kitty_json = out["kitties"][ind]

# %%
def parse_attributes(kitty_json):

    id = kitty_json["id"]
    name = kitty_json["name"]
    image = kitty_json["image_url_png"]
    generation = kitty_json["generation"]
    birthday = kitty_json["created_at"]
    color = kitty_json["color"]
    fancy = kitty_json["is_fancy"]
    fancy_type = kitty_json["fancy_type"]
    exclusive = kitty_json["is_exclusive"]
    cooldown = kitty_json["status"]["cooldown_index"]
    purrs = kitty_json["purrs"]["count"]
    watches = kitty_json["watchlist"]["count"]
    hatched = kitty_json["hatched"]
    prestige = kitty_json["is_prestige"]
    prestige_type = kitty_json["prestige_type"]
    prestige_ranking = kitty_json["prestige_ranking"]
    fancy_ranking = kitty_json["fancy_ranking"]

    if(len(kitty_json["enhanced_cattributes"]) == 0):

        body = None
        coloreyes = None
        eyes = None
        pattern = None
        mouth = None
        colorprimary = None
        colorsecondary = None
        colortertiary = None

    else:

        body = kitty_json["enhanced_cattributes"][0]["description"] #body
        coloreyes = kitty_json["enhanced_cattributes"][1]["description"] #coloreyes
        eyes = kitty_json["enhanced_cattributes"][2]["description"] #eyes
        pattern = kitty_json["enhanced_cattributes"][3]["description"] #pattern
        mouth = kitty_json["enhanced_cattributes"][4]["description"] #mouth
        colorprimary = kitty_json["enhanced_cattributes"][5]["description"] #colorprimary
        colorsecondary = kitty_json["enhanced_cattributes"][6]["description"] #colorsecondary
        colortertiary = kitty_json["enhanced_cattributes"][7]["description"] #colortertiary
    
    if(len(kitty_json["matron"]) == 0):
        
        mother_id = None
        mother_fancy = None
        mother_exclusive = None
        
    else:
        
        mother_id = kitty_json["matron"]["id"]
        mother_fancy = kitty_json["matron"]["is_fancy"]
        mother_exclusive = kitty_json["matron"]["is_exclusive"]
    
    
    if(len(kitty_json["sire"]) == 0):
        
        father_id = None
        father_fancy = None
        father_exclusive = None
        
    else:
        
        father_id = kitty_json["sire"]["id"]
        father_fancy = kitty_json["sire"]["is_fancy"]
        father_exclusive = kitty_json["sire"]["is_exclusive"]
    
    
    if(len(kitty_json["auction"]) == 0):
        
        start_price = None
        end_price = None
        current_price = None
        auction_type = None
        auction_start = None
        auction_end = None
        auction_duration = None
        
    else:
        
        start_price = kitty_json["auction"]["start_price"]
        end_price = kitty_json["auction"]["end_price"]
        current_price = kitty_json["auction"]["current_price"]
        auction_type = kitty_json["auction"]["type"]
        auction_start = kitty_json["auction"]["start_time"]
        auction_end = kitty_json["auction"]["end_time"]
        auction_duration = kitty_json["auction"]["duration"]
    
    return [id, name, image, generation, birthday, color, fancy,
    fancy_type, exclusive, cooldown, purrs, watches, hatched, 
    prestige, prestige_ranking, fancy_ranking, body, mouth, eyes,
    pattern, colorprimary, colorsecondary, colortertiary, coloreyes,
    mother_id, mother_fancy, mother_exclusive, father_id,
    father_fancy, father_exclusive, start_price, end_price,
    current_price, auction_type, auction_start, auction_end,
    auction_duration]

# %%
def kitties_to_sql(kitties_json, engine_string):
    
    kitty_list = [parse_attributes(kitty) for kitty in kitties_json["kitties"]]
    
    kitties_df = pd.DataFrame(kitty_list)
    kitties_df.drop(0, axis=1)
    
    column_names = ["id", "name", "image", "generation", "birthday", "color", "fancy",
    "fancy_type", "exclusive", "cooldown", "purrs", "watches", "hatched", 
    "prestige", "prestige_ranking", "fancy_ranking", "body", "mouth", "eyes",
    "pattern", "colorprimary", "colorsecondary", "colortertiary", "coloreyes",
    "mother_id", "mother_fancy", "mother_exclusive", "father_id",
    "father_fancy", "father_exclusive", "start_price", "end_price",
    "current_price", "auction_type", "auction_start", "auction_end",
    "auction_duration"]
    
    kitties_df.columns = column_names
    
    engine = create_connection(engine_string=engine_string)
    
    kitties_df.to_sql("kitties", engine, if_exists="append", index = False)
    
    return True

# %%
test = [parse_attributes(kitty) for kitty in out["kitties"]]

# %%
test
# Out:
# [[1,
#   'Genesis',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'sizzurp',
#   True,
#   'Genesis',
#   True,
#   0,
#   1587,
#   0,
#   True,
#   False,
#   None,
#   1,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [2,
#   'Riker | Founder Cat #2',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/2.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   84,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [3,
#   'Founder Cat #3',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/3.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   73,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [4,
#   'Fluffy Founder',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/4.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   2,
#   33,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [5,
#   'C-A-T-S Cats! Cats! Cats! - #5',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/5.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   72,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '600000000000000000000',
#   '600000000000000000000',
#   '600000000000000000000',
#   'sale',
#   '2018-03-25 14:30:59+00',
#   '2072-12-26 14:30:59+00',
#   '1728000000000'],
#  [6,
#   'æ¶¦é¾™ğŸ�±â€�ğŸ‘“åˆ›ä¸–çŒ«ç�‹6#',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/6.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   25,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [7,
#   'Lucky',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/7.png',
#   0,
#   '2017-11-23T06:19:59Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   23,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [8,
#   'Founder Cat #8',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/8.png',
#   0,
#   '2017-11-23T06:20:08Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   7,
#   66,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '888000000000000000000',
#   '888000000000000000000',
#   '888000000000000000000',
#   'sale',
#   '2017-12-17 17:49:04+00',
#   '2020-05-23 17:49:04+00',
#   '76723200000'],
#  [9,
#   'æ¶¦é¾™ğŸ�±â€�ğŸ‘“çŒ«ç�‹9#',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/9.png',
#   0,
#   '2017-11-23T06:20:35Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   25,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [10,
#   'Founder Cat #10',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/10.png',
#   0,
#   '2017-11-23T06:20:44Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   53,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [11,
#   'å°�çŒ« - wifey (1153122 temp)',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/11.png',
#   0,
#   '2017-11-23T06:20:44Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   13,
#   38,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [12,
#   'Founder Cat #12',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/12.png',
#   0,
#   '2017-11-23T06:20:44Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   10,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '8000000000000000000000',
#   '8000000000000000000000',
#   '8000000000000000000000',
#   'sale',
#   '2018-12-25 03:55:19+00',
#   '2019-01-24 03:55:19+00',
#   '2592000000'],
#  [13,
#   'Founder Flex #13',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/13.png',
#   0,
#   '2017-11-23T06:21:52Z',
#   'topaz',
#   False,
#   None,
#   False,
#   3,
#   16,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [14,
#   'Founder Cat #14',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/14.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   1,
#   8,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [15,
#   'Founder Cat #15',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/15.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   1,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [16,
#   'grey',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/16.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'topaz',
#   False,
#   None,
#   False,
#   1,
#   38,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '199000000000000000000',
#   '149000000000000000000',
#   '149000000000000000000',
#   'sale',
#   '2017-12-09 06:10:36+00',
#   '2017-12-11 06:10:36+00',
#   '172800000'],
#  [17,
#   'Founder Cat #17',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/17.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   32,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '199970000000000000000',
#   '177000000000000000000',
#   '177000000000000000000',
#   'sale',
#   '2018-02-24 03:29:47+00',
#   '2018-03-13 03:29:47+00',
#   '1468800000'],
#  [18,
#   'Founder Cat #18',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/18.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   5,
#   42,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '300000000000000000000',
#   '300000000000000000000',
#   '300000000000000000000',
#   'sale',
#   '2017-12-20 02:34:31+00',
#   '2017-12-27 02:34:31+00',
#   '604800000'],
#  [19,
#   'Founder Cat #19 MINT Virgin',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/19.png',
#   0,
#   '2017-11-23T06:21:56Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   25,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [20,
#   '#20 Never Been Licked',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/20.png',
#   0,
#   '2017-11-23T06:22:29Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   37,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '96000000000000000000',
#   '96000000000000000000',
#   '96000000000000000000',
#   'sale',
#   '2017-12-14 04:09:48+00',
#   '2072-09-16 04:09:48+00',
#   '1728000000000'],
#  [21,
#   'Founder Cat #21',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/21.png',
#   0,
#   '2017-11-23T06:22:29Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [22,
#   'Founder Cat #22',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/22.png',
#   0,
#   '2017-11-23T06:22:29Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   5,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [23,
#   'Founder Cat #23',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/23.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   25,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [24,
#   'Tomo | Founder Cat #24',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/24.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [25,
#   'Founder Cat #25',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/25.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   1,
#   3,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [26,
#   'Founder Cat #26',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/26.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   1,
#   35,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '96000000000000000000',
#   '96000000000000000000',
#   '96000000000000000000',
#   'sale',
#   '2017-12-14 03:39:58+00',
#   '2072-09-16 03:39:58+00',
#   '1728000000000'],
#  [27,
#   'Founder Cat #27',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/27.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   1,
#   16,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '150000000000000000000',
#   '99000000000000000000',
#   '99000000000000000000',
#   'sale',
#   '2018-01-04 12:27:22+00',
#   '2018-01-06 12:27:22+00',
#   '172800000'],
#  [28,
#   '@cryptodsl tweet 2 negotiate',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/28.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   23,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '250000000000000000000',
#   '250000000000000000000',
#   '250000000000000000000',
#   'sale',
#   '2017-12-22 23:53:01+00',
#   '2018-04-01 23:53:01+00',
#   '8640000000'],
#  [29,
#   '2105 Yards XXIX',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/29.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   19,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [30,
#   'www.wayi.cn æŒ–çŸ¿å°±æ‰¾æŒ–æ˜“',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/30.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   1,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [31,
#   'Founder Cat #31',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/31.png',
#   0,
#   '2017-11-23T06:23:59Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   11,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [32,
#   'ğŸ�± Founder Cat #32',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/32.png',
#   0,
#   '2017-11-23T06:24:41Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   13,
#   32,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [33,
#   'Founder Cat #33',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/33.png',
#   0,
#   '2017-11-23T06:24:48Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   5,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [34,
#   'AMANDA Founder Cat #34',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/34.png',
#   0,
#   '2017-11-23T06:24:48Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   3,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [35,
#   'ğŸ�±â€�ğŸ‘“æ‹›ã��çŒ«Founder Cat#35 VIRGIN',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/35.png',
#   0,
#   '2017-11-23T06:24:48Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   1,
#   10,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '100000000000000000000',
#   '100000000000000000000',
#   '100000000000000000000',
#   'sale',
#   '2017-12-13 08:37:35+00',
#   '2018-01-02 08:37:35+00',
#   '1728000000'],
#  [36,
#   'Scissor Team #36',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/36.png',
#   0,
#   '2017-11-23T06:24:48Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   6,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [37,
#   'Founder Cat #37',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/37.png',
#   0,
#   '2017-11-23T06:24:51Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   8,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [38,
#   'Founder Cat #38',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/38.png',
#   0,
#   '2017-11-23T06:25:02Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   14,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '130000000000000000000',
#   '130000000000000000000',
#   '130000000000000000000',
#   'sale',
#   '2017-12-14 03:28:24+00',
#   '2565-07-14 03:28:24+00',
#   '17280000000000'],
#  [39,
#   'ğŸ”¥GOODLUCKğŸ”¥',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/39.png',
#   0,
#   '2017-11-23T06:25:19Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   8,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '88000000000000000000',
#   '88000000000000000000',
#   '88000000000000000000',
#   'sire',
#   '2018-02-18 12:40:50+00',
#   '2020-07-25 12:40:50+00',
#   '76723200000'],
#  [40,
#   'Founder Cat #40',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/40.png',
#   0,
#   '2017-11-23T06:25:22Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   10,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [41,
#   'Founder #41',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/41.png',
#   0,
#   '2017-11-23T06:25:43Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [42,
#   "I'm kitty #42",
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/42.png',
#   0,
#   '2017-11-23T06:25:43Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   13,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [43,
#   'Founder Cat #43',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/43.png',
#   0,
#   '2017-11-23T06:25:57Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '188000000000000000000',
#   '228000000000000000000',
#   '228000000000000000000',
#   'sale',
#   '2017-12-07 17:15:05+00',
#   '2017-12-21 17:15:05+00',
#   '1209600000'],
#  [44,
#   'æ¶¦é¾™ğŸ�±â€�ğŸ‘“åˆ›ä¸–çŒ«ç�‹44#',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/44.png',
#   0,
#   '2017-11-23T06:26:15Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [45,
#   'Founder Cat #45',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/45.png',
#   0,
#   '2017-11-23T06:26:15Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [46,
#   'Follow the',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/46.png',
#   0,
#   '2017-11-23T06:26:43Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   2,
#   25,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2999000000000000000',
#   '2909000000000000000',
#   '2909000000000000000',
#   'sire',
#   '2018-01-20 18:50:48+00',
#   '2018-02-03 18:50:48+00',
#   '1209600000'],
#  [47,
#   'æ¶¦é¾™ğŸ�±â€�ğŸ‘“åˆ›ä¸–çŒ«ç�‹47#',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/47.png',
#   0,
#   '2017-11-23T06:26:43Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   5,
#   21,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [48,
#   'Tomcat Hanks',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/48.png',
#   0,
#   '2017-11-23T06:26:43Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [49,
#   'Founder #49',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/49.png',
#   0,
#   '2017-11-23T06:26:53Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [50,
#   'ALPHA INVESTMENTS',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/50.png',
#   0,
#   '2017-11-23T06:27:01Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [51,
#   'wayi.cn æŒ–çŸ¿æˆ‘ä»¬æ˜¯ä¸“ä¸šçš„',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/51.png',
#   0,
#   '2017-11-23T06:28:35Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   2,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [52,
#   'napoleon bonaparte',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/52.png',
#   0,
#   '2017-11-23T06:28:35Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   13,
#   5,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [53,
#   'Founder Cat #53',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/53.png',
#   0,
#   '2017-11-23T06:29:21Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   13,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [54,
#   'www.easy2mine.com  æŒ–çŸ¿æ‰¾æ˜“æ±\xa0',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/54.png',
#   0,
#   '2017-11-23T06:29:21Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   1,
#   3,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [55,
#   'Founder Cat #55',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/55.png',
#   0,
#   '2017-11-23T06:29:21Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   10,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '110000000000000000000',
#   '110000000000000000000',
#   '110000000000000000000',
#   'sale',
#   '2017-12-19 02:18:21+00',
#   '2017-12-24 02:18:21+00',
#   '432000000'],
#  [56,
#   'Founder Cat #56',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/56.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [57,
#   'Founder Cat #57',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/57.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [58,
#   'Founder Cat #58',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/58.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [59,
#   'bought a dumb founder',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/59.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '89000000000000000000',
#   '89000000000000000000',
#   '89000000000000000000',
#   'sale',
#   '2018-10-15 16:47:36+00',
#   '2019-01-12 16:47:36+00',
#   '7689600000'],
#  [60,
#   'Founder Cat #60',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/60.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [61,
#   'Golden Horatio #61',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/61.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   8,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [62,
#   'æ¶¦é¾™ğŸ�±â€�ğŸ‘“æ‹›ã��çŒ«FounderCat#62',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/62.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [63,
#   'Founder Cat #63',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/63.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [64,
#   'Meowyl Streep',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/64.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   5,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [65,
#   '#65 - Dom Chestnut',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/65.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   8,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [66,
#   'Founder Cat #66  è�Œè�Œçš„å¤§ç’¨ç’¨',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/66.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [67,
#   'Founder Cat #67',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/67.png',
#   0,
#   '2017-11-23T06:29:55Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '48000000000000000000',
#   '98000000000000000000',
#   '98000000000000000000',
#   'sale',
#   '2017-12-11 19:02:18+00',
#   '2017-12-12 07:02:18+00',
#   '43200000'],
#  [68,
#   'Founder Cat #68',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/68.png',
#   0,
#   '2017-11-23T06:30:34Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [69,
#   'Founder Cat #69',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/69.png',
#   0,
#   '2017-11-23T06:30:39Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   13,
#   13,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [70,
#   'Founder Cat #70',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/70.png',
#   0,
#   '2017-11-23T06:30:39Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   2,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [71,
#   '#71',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/71.png',
#   0,
#   '2017-11-23T06:30:39Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   13,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [72,
#   'FRANK PUSSITANO',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/72.png',
#   0,
#   '2017-11-23T06:31:02Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [73,
#   'Founder Cat #73',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/73.png',
#   0,
#   '2017-11-23T06:31:02Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   4,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [74,
#   'Founder Cat #74',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/74.png',
#   0,
#   '2017-11-23T06:31:02Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   13,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [75,
#   'Ragamuffin -  Founder',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/75.png',
#   0,
#   '2017-11-23T06:31:13Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   13,
#   10,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [76,
#   'Founder Cat #76',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/76.png',
#   0,
#   '2017-11-23T06:31:33Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   13,
#   13,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [77,
#   'Double Lucky #77',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/77.png',
#   0,
#   '2017-11-23T06:31:33Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   3,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [78,
#   'Founder Cat #78',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/78.png',
#   0,
#   '2017-11-23T06:31:55Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   5,
#   10,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '15000000000000000000',
#   '15000000000000000000',
#   '15000000000000000000',
#   'sire',
#   '2017-12-08 10:01:17+00',
#   '2017-12-13 10:01:17+00',
#   '432000000'],
#  [79,
#   'Founder Cat #79',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/79.png',
#   0,
#   '2017-11-23T06:31:55Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   11,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [80,
#   'Founder Cat #80',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/80.png',
#   0,
#   '2017-11-23T06:33:17Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [81,
#   'Yuuuuuuu',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/81.png',
#   0,
#   '2017-11-23T06:33:17Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   13,
#   21,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '27000000000000000000',
#   '25000000000000000000',
#   '26885946026672100000',
#   'sale',
#   '2019-05-08 02:41:29+00',
#   '2019-06-07 02:41:29+00',
#   '2592000000'],
#  [82,
#   'QUAVO',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/82.png',
#   0,
#   '2017-11-23T06:33:17Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '1000000000000000000000',
#   '1000000000000000000000',
#   '1000000000000000000000',
#   'sale',
#   '2018-11-28 02:00:47+00',
#   '2021-08-24 02:00:47+00',
#   '86400000000'],
#  [83,
#   'OFFSET',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/83.png',
#   0,
#   '2017-11-23T06:33:17Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [84,
#   'Broken Genes',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/84.png',
#   0,
#   '2017-11-23T06:33:21Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   13,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [85,
#   'Founder Cat #85',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/85.png',
#   0,
#   '2017-11-23T06:33:21Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   3,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '29900000000000000000',
#   '29900000000000000000',
#   '29900000000000000000',
#   'sale',
#   '2019-03-17 17:04:05+00',
#   '2019-06-13 17:04:05+00',
#   '7603200000'],
#  [86,
#   'Founder Cat #86',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/86.png',
#   0,
#   '2017-11-23T06:33:21Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [87,
#   'Virgin with Beard & Jaguar',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/87.png',
#   0,
#   '2017-11-23T06:33:21Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '1888000000000000000000',
#   '1688000000000000000000',
#   '1688000000000000000000',
#   'sale',
#   '2017-12-06 19:13:37+00',
#   '2017-12-13 19:13:37+00',
#   '604800000'],
#  [88,
#   'Lucky Founder Cat #88',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/88.png',
#   0,
#   '2017-11-23T06:33:21Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'beard',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [89,
#   'VOLTRON',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/89.png',
#   0,
#   '2017-11-23T06:34:27Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [90,
#   'TAKEOFF',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/90.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   8,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'beard',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [91,
#   'Founder Cat #91',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/91.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '35000000000000000000',
#   '35000000000000000000',
#   '35000000000000000000',
#   'sale',
#   '2019-04-19 16:16:36+00',
#   '2019-04-21 16:16:36+00',
#   '172800000'],
#  [92,
#   'Founder Cat #92',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/92.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   13,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [93,
#   '#93 - Simple Dominant',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/93.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'topaz',
#   False,
#   None,
#   False,
#   13,
#   13,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [94,
#   'Founder Cat #94',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/94.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   13,
#   7,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [95,
#   'æˆ�å†› Founder Cat #95',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/95.png',
#   0,
#   '2017-11-23T06:34:31Z',
#   'chestnut',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'chestnut',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [96,
#   'LIZ LEMON',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/96.png',
#   0,
#   '2017-11-23T06:34:49Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   13,
#   12,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'crazy',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [97,
#   'Founder Cat #97',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/97.png',
#   0,
#   '2017-11-23T06:35:09Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   6,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'chocolate',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [98,
#   'MEDY Founder Cat #98',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/98.png',
#   0,
#   '2017-11-23T06:35:46Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   14,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'lemonade',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [99,
#   'Eternal Emperor Founder Cat 99',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/99.png',
#   0,
#   '2017-11-23T06:36:07Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   9,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'simple',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '168000000000000000000',
#   '100000000000000000000',
#   '100000000000000000000',
#   'sale',
#   '2017-12-16 16:56:16+00',
#   '2017-12-23 16:56:16+00',
#   '604800000'],
#  [100,
#   'Founder Cat #ğŸ’¯',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/100.png',
#   0,
#   '2017-11-23T06:36:07Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   15,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'beard',
#   'thicccbrowz',
#   'jaguar',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [101,
#   'BugCat',
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/101.png',
#   0,
# ...
#   None,
#   None],
#  [965,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/965.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'thicccbrowz',
#   'totesbasic',
#   'salmon',
#   'lemonade',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [966,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/966.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'royalpurple',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [967,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/967.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'royalpurple',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [968,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/968.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'crazy',
#   'luckystripe',
#   'shadowgrey',
#   'royalpurple',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [969,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/969.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'crazy',
#   'luckystripe',
#   'aquamarine',
#   'lemonade',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [970,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/970.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'soserious',
#   'crazy',
#   'luckystripe',
#   'orangesoda',
#   'coffee',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [971,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/971.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'swampgreen',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [972,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/972.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'crazy',
#   'luckystripe',
#   'aquamarine',
#   'swampgreen',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [973,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/973.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'greymatter',
#   'coffee',
#   'granitegrey',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [974,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/974.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'greymatter',
#   'chocolate',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [975,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/975.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'crazy',
#   'luckystripe',
#   'shadowgrey',
#   'coffee',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [976,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/976.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'chocolate',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [977,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/977.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'crazy',
#   'totesbasic',
#   'salmon',
#   'chocolate',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [978,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/978.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'crazy',
#   'luckystripe',
#   'salmon',
#   'lemonade',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [979,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/979.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'munchkin',
#   'pouty',
#   'thicccbrowz',
#   'totesbasic',
#   'shadowgrey',
#   'lemonade',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [980,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/980.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [981,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/981.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'luckystripe',
#   'shadowgrey',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [982,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/982.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'crazy',
#   'totesbasic',
#   'shadowgrey',
#   'royalpurple',
#   'kittencream',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [983,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/983.png',
#   0,
#   '2017-11-23T09:15:50Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'crazy',
#   'luckystripe',
#   'shadowgrey',
#   'lemonade',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [984,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/984.png',
#   0,
#   '2017-11-23T09:16:21Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'thicccbrowz',
#   'luckystripe',
#   'aquamarine',
#   'coffee',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [985,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/985.png',
#   0,
#   '2017-11-23T09:16:21Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'soserious',
#   'thicccbrowz',
#   'totesbasic',
#   'aquamarine',
#   'chocolate',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [986,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/986.png',
#   0,
#   '2017-11-23T09:16:21Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'thicccbrowz',
#   'totesbasic',
#   'orangesoda',
#   'royalpurple',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [987,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/987.png',
#   0,
#   '2017-11-23T09:16:30Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'thicccbrowz',
#   'totesbasic',
#   'salmon',
#   'swampgreen',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [988,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/988.png',
#   0,
#   '2017-11-23T09:16:57Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'crazy',
#   'totesbasic',
#   'orangesoda',
#   'coffee',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [989,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/989.png',
#   0,
#   '2017-11-23T09:16:57Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'luckystripe',
#   'shadowgrey',
#   'coffee',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [990,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/990.png',
#   0,
#   '2017-11-23T09:16:57Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'salmon',
#   'chocolate',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [991,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/991.png',
#   0,
#   '2017-11-23T09:17:15Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'thicccbrowz',
#   'luckystripe',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [992,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/992.png',
#   0,
#   '2017-11-23T09:17:15Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'coffee',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [993,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/993.png',
#   0,
#   '2017-11-23T09:17:24Z',
#   'sizzurp',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'soserious',
#   'thicccbrowz',
#   'totesbasic',
#   'salmon',
#   'lemonade',
#   'kittencream',
#   'sizzurp',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [994,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/994.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'topaz',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'pouty',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'chocolate',
#   'granitegrey',
#   'topaz',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [995,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/995.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'pouty',
#   'thicccbrowz',
#   'totesbasic',
#   'salmon',
#   'chocolate',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [996,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/996.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'soserious',
#   'thicccbrowz',
#   'totesbasic',
#   'greymatter',
#   'chocolate',
#   'granitegrey',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [997,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/997.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'thicccbrowz',
#   'totesbasic',
#   'salmon',
#   'lemonade',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [998,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/998.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'ragamuffin',
#   'happygokitty',
#   'thicccbrowz',
#   'luckystripe',
#   'orangesoda',
#   'royalpurple',
#   'kittencream',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [999,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/999.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'strawberry',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'himalayan',
#   'happygokitty',
#   'thicccbrowz',
#   'totesbasic',
#   'orangesoda',
#   'swampgreen',
#   'granitegrey',
#   'strawberry',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [1000,
#   None,
#   'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1000.png',
#   0,
#   '2017-11-23T09:18:57Z',
#   'mintgreen',
#   False,
#   None,
#   False,
#   0,
#   0,
#   0,
#   True,
#   False,
#   None,
#   None,
#   'sphynx',
#   'happygokitty',
#   'crazy',
#   'totesbasic',
#   'aquamarine',
#   'swampgreen',
#   'kittencream',
#   'mintgreen',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ...]

# %%
test_df = pd.DataFrame(test)

# %%
test_df.drop(0, axis=1)
# Out:
#                                    1   \
# 0                             Genesis
# 1              Riker | Founder Cat #2
# 2                      Founder Cat #3
# 3                      Fluffy Founder
# 4      C-A-T-S Cats! Cats! Cats! - #5
# 5     æ¶¦é¾™ğŸ�±â€�ğŸ‘“åˆ›ä¸–çŒ«ç�‹6#
# 6                               Lucky
# 7                      Founder Cat #8
# 8           æ¶¦é¾™ğŸ�±â€�ğŸ‘“çŒ«ç�‹9#
# 9                     Founder Cat #10
# 10      å°�çŒ« - wifey (1153122 temp)
# 11                    Founder Cat #12
# 12                   Founder Flex #13
# 13                    Founder Cat #14
# 14                    Founder Cat #15
# 15                               grey
# 16                    Founder Cat #17
# 17                    Founder Cat #18
# 18        Founder Cat #19 MINT Virgin
# 19              #20 Never Been Licked
# 20                    Founder Cat #21
# 21                    Founder Cat #22
# 22                    Founder Cat #23
# 23             Tomo | Founder Cat #24
# 24                    Founder Cat #25
# 25                    Founder Cat #26
# 26                    Founder Cat #27
# 27       @cryptodsl tweet 2 negotiate
# 28                    2105 Yards XXIX
# 29     www.wayi.cn æŒ–çŸ¿å°±æ‰¾æŒ–æ˜“
# ...                               ...
# 9970                             9971
# 9971                       TomTomğŸ¦Š
# 9972                     Katterpitter
# 9973                     Grape - Gen4
# 9974                        Fleckchen
# 9975               KristapsPorzingcat
# 9976                       JB 2nd gen
# 9977                      Noodle Poof
# 9978                      CrazyGranit
# 9979                   Phyrexian Meow
# 9980                             None
# 9981                             None
# 9982                       Almost Tom
# 9983   Unique Combo:#2 Wingtips+Beard
# 9984                      Black Peter
# 9985                 Dance Ridiculous
# 9986                             None
# 9987                           Milcat
# 9988             Rare Tigerpunk Gene!
# 9989                              Cow
# 9990                           Gen 15
# 9991                     Floury Meows
# 9992     Sell Mr. Grumpers the RoyalP
# 9993                        boomer G1
# 9994                     BTCWILLCRASH
# 9995                      Brady Claws
# 9996                     Kind-o-Nasty
# 9997                       Bai - Gen4
# 9998      #9999 - SkydivingInstructor
# 9999            Kitty #10000 Wingtips
#
#                                                      2   3   \
# 0     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 1     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 2     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 3     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 4     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 5     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 6     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 7     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 8     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 9     https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 10    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 11    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 12    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 13    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 14    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 15    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 16    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 17    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 18    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 19    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 20    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 21    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 22    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 23    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 24    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 25    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 26    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 27    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 28    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# 29    https://img.cryptokitties.co/0x06012c8cf97bead...   0
# ...                                                 ...  ..
# 9970  https://img.cryptokitties.co/0x06012c8cf97bead...  18
# 9971  https://img.cryptokitties.co/0x06012c8cf97bead...  11
# 9972  https://img.cryptokitties.co/0x06012c8cf97bead...  15
# 9973  https://img.cryptokitties.co/0x06012c8cf97bead...   4
# 9974  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9975  https://img.cryptokitties.co/0x06012c8cf97bead...  13
# 9976  https://img.cryptokitties.co/0x06012c8cf97bead...  14
# 9977  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9978  https://img.cryptokitties.co/0x06012c8cf97bead...  17
# 9979  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9980  https://img.cryptokitties.co/0x06012c8cf97bead...  11
# 9981  https://img.cryptokitties.co/0x06012c8cf97bead...  15
# 9982  https://img.cryptokitties.co/0x06012c8cf97bead...  14
# 9983  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9984  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9985  https://img.cryptokitties.co/0x06012c8cf97bead...  18
# 9986  https://img.cryptokitties.co/0x06012c8cf97bead...  19
# 9987  https://img.cryptokitties.co/0x06012c8cf97bead...  14
# 9988  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9989  https://img.cryptokitties.co/0x06012c8cf97bead...  17
# 9990  https://img.cryptokitties.co/0x06012c8cf97bead...  15
# 9991  https://img.cryptokitties.co/0x06012c8cf97bead...  19
# 9992  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9993  https://img.cryptokitties.co/0x06012c8cf97bead...   1
# 9994  https://img.cryptokitties.co/0x06012c8cf97bead...  16
# 9995  https://img.cryptokitties.co/0x06012c8cf97bead...  17
# 9996  https://img.cryptokitties.co/0x06012c8cf97bead...   7
# 9997  https://img.cryptokitties.co/0x06012c8cf97bead...   4
# 9998  https://img.cryptokitties.co/0x06012c8cf97bead...  12
# 9999  https://img.cryptokitties.co/0x06012c8cf97bead...  16
#
#                         4           5      6        7      8   9     10  ...  \
# 0     2017-11-23T06:19:59Z     sizzurp   True  Genesis   True   0  1587  ...
# 1     2017-11-23T06:19:59Z    chestnut  False     None  False   0    84  ...
# 2     2017-11-23T06:19:59Z  strawberry  False     None  False   0    73  ...
# 3     2017-11-23T06:19:59Z    chestnut  False     None  False   2    33  ...
# 4     2017-11-23T06:19:59Z    chestnut  False     None  False   0    72  ...
# 5     2017-11-23T06:19:59Z   mintgreen  False     None  False   0    25  ...
# 6     2017-11-23T06:19:59Z       topaz  False     None  False   0    23  ...
# 7     2017-11-23T06:20:08Z     sizzurp  False     None  False   7    66  ...
# 8     2017-11-23T06:20:35Z   mintgreen  False     None  False   0    25  ...
# 9     2017-11-23T06:20:44Z    chestnut  False     None  False   0    53  ...
# 10    2017-11-23T06:20:44Z     sizzurp  False     None  False  13    38  ...
# 11    2017-11-23T06:20:44Z   mintgreen  False     None  False  10    12  ...
# 12    2017-11-23T06:21:52Z       topaz  False     None  False   3    16  ...
# 13    2017-11-23T06:21:56Z  strawberry  False     None  False   1     8  ...
# 14    2017-11-23T06:21:56Z    chestnut  False     None  False   1     9  ...
# 15    2017-11-23T06:21:56Z       topaz  False     None  False   1    38  ...
# 16    2017-11-23T06:21:56Z       topaz  False     None  False   0    32  ...
# 17    2017-11-23T06:21:56Z   mintgreen  False     None  False   5    42  ...
# 18    2017-11-23T06:21:56Z  strawberry  False     None  False   0    25  ...
# 19    2017-11-23T06:22:29Z  strawberry  False     None  False   0    37  ...
# 20    2017-11-23T06:22:29Z       topaz  False     None  False  13     7  ...
# 21    2017-11-23T06:22:29Z   mintgreen  False     None  False   5     7  ...
# 22    2017-11-23T06:23:59Z  strawberry  False     None  False   0    25  ...
# 23    2017-11-23T06:23:59Z    chestnut  False     None  False   0     6  ...
# 24    2017-11-23T06:23:59Z    chestnut  False     None  False   1     3  ...
# 25    2017-11-23T06:23:59Z  strawberry  False     None  False   1    35  ...
# 26    2017-11-23T06:23:59Z     sizzurp  False     None  False   1    16  ...
# 27    2017-11-23T06:23:59Z     sizzurp  False     None  False   0    23  ...
# 28    2017-11-23T06:23:59Z       topaz  False     None  False   0    19  ...
# 29    2017-11-23T06:23:59Z    chestnut  False     None  False   1     6  ...
# ...                    ...         ...    ...      ...    ...  ..   ...  ...
# 9970  2017-11-28T12:48:54Z   bubblegum  False     None  False  11     1  ...
# 9971  2017-11-28T12:49:02Z     sizzurp  False     None  False  10     1  ...
# 9972  2017-11-28T12:49:55Z   mintgreen  False     None  False  13     0  ...
# 9973  2017-11-28T12:50:00Z       topaz  False     None  False   2     0  ...
# 9974  2017-11-28T12:56:24Z  strawberry  False     None  False  10     0  ...
# 9975  2017-11-28T12:56:54Z       topaz  False     None  False   9     1  ...
# 9976  2017-11-28T12:58:55Z  strawberry  False     None  False  12     0  ...
# 9977  2017-11-28T13:06:43Z   mintgreen  False     None  False  12     0  ...
# 9978  2017-11-28T13:08:14Z  strawberry  False     None  False  13     0  ...
# 9979  2017-11-28T13:08:14Z   limegreen  False     None  False  12     0  ...
# 9980  2017-11-28T13:10:43Z   limegreen  False     None  False   6     0  ...
# 9981  2017-11-28T13:18:11Z       topaz  False     None  False   8     4  ...
# 9982  2017-11-28T13:19:15Z     sizzurp  False     None  False   9     0  ...
# 9983  2017-11-28T13:19:15Z  strawberry  False     None  False  11     1  ...
# 9984  2017-11-28T13:19:15Z       topaz  False     None  False  10     1  ...
# 9985  2017-11-28T13:19:15Z     sizzurp  False     None  False   9     0  ...
# 9986  2017-11-28T13:19:23Z  strawberry  False     None  False  12     0  ...
# 9987  2017-11-28T13:19:23Z   mintgreen  False     None  False   8     0  ...
# 9988  2017-11-28T13:19:23Z     sizzurp  False     None  False  12     0  ...
# 9989  2017-11-28T13:21:16Z       topaz  False     None  False  12     0  ...
# 9990  2017-11-28T13:24:38Z       topaz  False     None  False  12     1  ...
# 9991  2017-11-28T13:24:38Z       topaz  False     None  False  10     0  ...
# 9992  2017-11-28T13:26:54Z   mintgreen  False     None  False  13     0  ...
# 9993  2017-11-28T13:28:30Z   mintgreen  False     None  False   9     2  ...
# 9994  2017-11-28T13:28:30Z   mintgreen  False     None  False  12     0  ...
# 9995  2017-11-28T13:28:30Z       topaz  False     None  False  10     0  ...
# 9996  2017-11-28T13:28:30Z     sizzurp  False     None  False   6     0  ...
# 9997  2017-11-28T13:30:22Z    chestnut  False     None  False   5     0  ...
# 9998  2017-11-28T13:32:33Z     sizzurp  False     None  False   9     2  ...
# 9999  2017-11-28T13:32:33Z       topaz  False     None  False   9     9  ...
#
#           27     28     29                      30                      31  \
# 0        NaN   None   None                    None                    None
# 1        NaN   None   None                    None                    None
# 2        NaN   None   None                    None                    None
# 3        NaN   None   None                    None                    None
# 4        NaN   None   None   600000000000000000000   600000000000000000000
# 5        NaN   None   None                    None                    None
# 6        NaN   None   None                    None                    None
# 7        NaN   None   None   888000000000000000000   888000000000000000000
# 8        NaN   None   None                    None                    None
# 9        NaN   None   None                    None                    None
# 10       NaN   None   None                    None                    None
# 11       NaN   None   None  8000000000000000000000  8000000000000000000000
# 12       NaN   None   None                    None                    None
# 13       NaN   None   None                    None                    None
# 14       NaN   None   None                    None                    None
# 15       NaN   None   None   199000000000000000000   149000000000000000000
# 16       NaN   None   None   199970000000000000000   177000000000000000000
# 17       NaN   None   None   300000000000000000000   300000000000000000000
# 18       NaN   None   None                    None                    None
# 19       NaN   None   None    96000000000000000000    96000000000000000000
# 20       NaN   None   None                    None                    None
# 21       NaN   None   None                    None                    None
# 22       NaN   None   None                    None                    None
# 23       NaN   None   None                    None                    None
# 24       NaN   None   None                    None                    None
# 25       NaN   None   None    96000000000000000000    96000000000000000000
# 26       NaN   None   None   150000000000000000000    99000000000000000000
# 27       NaN   None   None   250000000000000000000   250000000000000000000
# 28       NaN   None   None                    None                    None
# 29       NaN   None   None                    None                    None
# ...      ...    ...    ...                     ...                     ...
# 9970  7968.0  False  False                    None                    None
# 9971  5102.0  False  False                    None                    None
# 9972  6375.0  False  False                    None                    None
# 9973  9942.0  False  False                    None                    None
# 9974  8257.0  False  False                    None                    None
# 9975  6947.0  False  False     1100000000000000000      400000000000000000
# 9976  7746.0  False  False                    None                    None
# 9977  7198.0  False  False                    None                    None
# 9978  7049.0  False  False                    None                    None
# 9979  5595.0  False  False                    None                    None
# 9980  6639.0  False  False                    None                    None
# 9981  4632.0  False  False                    None                    None
# 9982  5076.0  False  False                    None                    None
# 9983  9653.0  False  False     5000000000000000000     1900000000000000000
# 9984  5562.0  False  False                    None                    None
# 9985  2427.0  False  False                    None                    None
# 9986  8452.0  False  False                    None                    None
# 9987  3790.0  False  False                    None                    None
# 9988  9911.0  False  False                    None                    None
# 9989  9629.0  False  False                    None                    None
# 9990  6442.0  False  False                    None                    None
# 9991  7880.0  False  False                    None                    None
# 9992  7050.0  False  False                    None                    None
# 9993  2713.0  False  False       80000000000000000       45000000000000000
# 9994  8660.0  False  False                    None                    None
# 9995  7921.0  False  False                    None                    None
# 9996  5797.0  False  False                    None                    None
# 9997  9928.0  False  False                    None                    None
# 9998  8919.0  False  False                    None                    None
# 9999  7167.0  False  False    19000000000000000000    19234000000000000000
#
#                           32    33                      34  \
# 0                       None  None                    None
# 1                       None  None                    None
# 2                       None  None                    None
# 3                       None  None                    None
# 4      600000000000000000000  sale  2018-03-25 14:30:59+00
# 5                       None  None                    None
# 6                       None  None                    None
# 7      888000000000000000000  sale  2017-12-17 17:49:04+00
# 8                       None  None                    None
# 9                       None  None                    None
# 10                      None  None                    None
# 11    8000000000000000000000  sale  2018-12-25 03:55:19+00
# 12                      None  None                    None
# 13                      None  None                    None
# 14                      None  None                    None
# 15     149000000000000000000  sale  2017-12-09 06:10:36+00
# 16     177000000000000000000  sale  2018-02-24 03:29:47+00
# 17     300000000000000000000  sale  2017-12-20 02:34:31+00
# 18                      None  None                    None
# 19      96000000000000000000  sale  2017-12-14 04:09:48+00
# 20                      None  None                    None
# 21                      None  None                    None
# 22                      None  None                    None
# 23                      None  None                    None
# 24                      None  None                    None
# 25      96000000000000000000  sale  2017-12-14 03:39:58+00
# 26      99000000000000000000  sale  2018-01-04 12:27:22+00
# 27     250000000000000000000  sale  2017-12-22 23:53:01+00
# 28                      None  None                    None
# 29                      None  None                    None
# ...                      ...   ...                     ...
# 9970                    None  None                    None
# 9971                    None  None                    None
# 9972                    None  None                    None
# 9973                    None  None                    None
# 9974                    None  None                    None
# 9975      400000000000000000  sale  2017-12-16 10:58:39+00
# 9976                    None  None                    None
# 9977                    None  None                    None
# 9978                    None  None                    None
# 9979                    None  None                    None
# 9980                    None  None                    None
# 9981                    None  None                    None
# 9982                    None  None                    None
# 9983     1900000000000000000  sale  2017-12-25 02:11:13+00
# 9984                    None  None                    None
# 9985                    None  None                    None
# 9986                    None  None                    None
# 9987                    None  None                    None
# 9988                    None  None                    None
# 9989                    None  None                    None
# 9990                    None  None                    None
# 9991                    None  None                    None
# 9992                    None  None                    None
# 9993       45000000000000000  sire  2017-12-12 00:49:32+00
# 9994                    None  None                    None
# 9995                    None  None                    None
# 9996                    None  None                    None
# 9997                    None  None                    None
# 9998                    None  None                    None
# 9999    19234000000000000000  sale  2017-12-12 15:09:24+00
#
#                           35             36
# 0                       None           None
# 1                       None           None
# 2                       None           None
# 3                       None           None
# 4     2072-12-26 14:30:59+00  1728000000000
# 5                       None           None
# 6                       None           None
# 7     2020-05-23 17:49:04+00    76723200000
# 8                       None           None
# 9                       None           None
# 10                      None           None
# 11    2019-01-24 03:55:19+00     2592000000
# 12                      None           None
# 13                      None           None
# 14                      None           None
# 15    2017-12-11 06:10:36+00      172800000
# 16    2018-03-13 03:29:47+00     1468800000
# 17    2017-12-27 02:34:31+00      604800000
# 18                      None           None
# 19    2072-09-16 04:09:48+00  1728000000000
# 20                      None           None
# 21                      None           None
# 22                      None           None
# 23                      None           None
# 24                      None           None
# 25    2072-09-16 03:39:58+00  1728000000000
# 26    2018-01-06 12:27:22+00      172800000
# 27    2018-04-01 23:53:01+00     8640000000
# 28                      None           None
# 29                      None           None
# ...                      ...            ...
# 9970                    None           None
# 9971                    None           None
# 9972                    None           None
# 9973                    None           None
# 9974                    None           None
# 9975  2017-12-18 10:58:39+00      172800000
# 9976                    None           None
# 9977                    None           None
# 9978                    None           None
# 9979                    None           None
# 9980                    None           None
# 9981                    None           None
# 9982                    None           None
# 9983  2017-12-26 02:11:13+00       86400000
# 9984                    None           None
# 9985                    None           None
# 9986                    None           None
# 9987                    None           None
# 9988                    None           None
# 9989                    None           None
# 9990                    None           None
# 9991                    None           None
# 9992                    None           None
# 9993  2017-12-13 12:49:32+00      129600000
# 9994                    None           None
# 9995                    None           None
# 9996                    None           None
# 9997                    None           None
# 9998                    None           None
# 9999  2017-12-14 15:09:24+00      172800000
#
# [10000 rows x 36 columns]

# %%
column_names = ["id", "name", "image", "generation", "birthday", "color", "fancy",
    "fancy_type", "exclusive", "cooldown", "purrs", "watches", "hatched", 
    "prestige", "prestige_ranking", "fancy_ranking", "body", "mouth", "eyes",
    "pattern", "colorprimary", "colorsecondary", "colortertiary", "coloreyes",
    "mother_id", "mother_fancy", "mother_exclusive", "father_id",
    "father_fancy", "father_exclusive", "start_price", "end_price",
    "current_price", "auction_type", "auction_start", "auction_end",
    "auction_duration"]

# %%
test_df.columns = column_names

# %%
def create_connection(host='127.0.0.1', database="", sqltype="mysql+pymysql", port=3308,
                      user_env="amazonRDS_user", password_env="amazonRDS_pw",
                      username=None, password=None, dbconfig=None, engine_string=None):

    if engine_string is None:
        if dbconfig is not None:
            with open(dbconfig, "r") as f:
                db = yaml.load(f)

            host = db["host"]
            database = ifin("dbname", db, "")
            sqltype = ifin("type", db, sqltype)
            port = db["port"]
            user_env = db["user_env"]
            password_env = db["password_env"]

        username = os.environ.get(user_env) if username is None else username
        password = os.environ.get(password_env) if password is None else password

        engine_string = "{sqltype}://{username}:{password}@{host}:{port}/{database}"
        engine_string = engine_string.format(sqltype=sqltype, username=username,
                                             password=password, host=host, port=port, database=database)

    conn = sqlalchemy.create_engine(engine_string)

    return conn

def get_session(engine=None, engine_string=None):
    """

    Args:
        engine_string: SQLAlchemy connection string in the form of:

            "{sqltype}://{username}:{password}@{host}:{port}/{database}"

    Returns:
        SQLAlchemy session
    """

    if engine is None and engine_string is None:
        return ValueError("`engine` or `engine_string` must be provided")
    elif engine is None:
        engine = create_connection(engine_string=engine_string)

    Session = sessionmaker(bind=engine)
    session = Session()

    return session

engine_string='sqlite:///../data/kitties.db'
engine = create_connection(engine_string=engine_string)
session = get_session(engine_string=engine_string)

# %%
test_df.to_sql("kitties", engine, if_exists="append", index = False)

# %%
def land_kitties(engine_string, bucket = "jdc-nu", access_id = os.environ["AWS_ACCESS_ID"], access_key = os.environ["AWS_ACCESS_KEY"]):

    s3 = boto3.resource('s3',
                    aws_access_key_id=access_id,
                    aws_secret_access_key=access_key)

    files = get_s3_file_names(s3, "s3://jdc-nu")

    cntr = 0
    for file in files:

        kitties_json = load_kitty_json(file, s3, bucket)
        kitties_to_sql(kitties_json, engine_string)

        cntr = cntr + len(kitties_json["kitties"])
        print(cntr)

    return

# %%
engine_string='sqlite:///../data/kitties.db'
bucket = "jdc-nu"
access_id = os.environ["AWS_ACCESS_ID"]
access_key = os.environ["AWS_ACCESS_KEY"]

# %%
land_kitties(engine_string, bucket, access_id, access_key)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-12c56e5b32f1> in <module>
# ----> 1 land_kitties(engine_string, bucket, access_id, access_key)
#
# <ipython-input-211-890fd3bf6ccd> in land_kitties(engine_string, bucket, access_id, access_key)
#      10     for file in files:
#      11
# ---> 12         kitties_json = load_kitty_json(file, s3, bucket)
#      13         kitties_to_sql(kitties_json, engine_string)
#      14
#
# <ipython-input-202-a335d2a34cd2> in load_kitty_json(file, s3, bucket)
#       2
#       3     obj = s3.Object(bucket,file)
# ----> 4     file_content = obj.get()['Body'].read().decode('utf-8')
#       5     json_content = json.loads(file_content)
#       6
#
# c:\users\jd cook\anaconda3\envs\avc\lib\site-packages\botocore\response.py in read(self, amt)
#      76         """
#      77         try:
# ---> 78             chunk = self._raw_stream.read(amt)
#      79         except URLLib3ReadTimeoutError as e:
#      80             # TODO: the url will be None as urllib3 isn't setting it yet
#
# c:\users\jd cook\anaconda3\envs\avc\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     436             if amt is None:
#     437                 # cStringIO doesn't like amt=None
# --> 438                 data = self._fp.read()
#     439                 flush_decoder = True
#     440             else:
#
# c:\users\jd cook\anaconda3\envs\avc\lib\http\client.py in read(self, amt)
#     458             else:
#     459                 try:
# --> 460                     s = self._safe_read(self.length)
#     461                 except IncompleteRead:
#     462                     self._close_conn()
#
# c:\users\jd cook\anaconda3\envs\avc\lib\http\client.py in _safe_read(self, amt)
#     608         s = []
#     609         while amt > 0:
# --> 610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
#     612                 raise IncompleteRead(b''.join(s), amt)
#
# c:\users\jd cook\anaconda3\envs\avc\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\users\jd cook\anaconda3\envs\avc\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\jd cook\anaconda3\envs\avc\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
engine_string='sqlite:///../data/kitties.db'
engine = create_connection(engine_string=engine_string)

# %%
kitty_data = pd.read_sql("select * from kitties", engine)

# %%
training = kitty_data[kitty_data.auction_type == "sale"]
#validation = kitty_data[kitty_data.auction_type != "sale"]

# %%
training.loc[:,["current_price"]] = training.loc[:,["current_price"]]*.0000000000001

# %%
training["current_price"]
# Out:
# 4         6.000000e+07
# 7         8.880000e+07
# 11        8.000000e+08
# 15        1.490000e+07
# 16        1.770000e+07
# 17        3.000000e+07
# 19        9.600000e+06
# 25        9.600000e+06
# 26        9.900000e+06
# 27        2.500000e+07
# 34        1.000000e+07
# 37        1.300000e+07
# 42        2.280000e+07
# 54        1.100000e+07
# 58        8.900000e+06
# 66        9.800000e+06
# 80        2.688595e+06
# 81        1.000000e+08
# 84        2.990000e+06
# 86        1.688000e+08
# 90        3.500000e+06
# 98        1.000000e+07
# 106       5.000000e+06
# 107       2.351135e+06
# 109       5.000000e+06
# 112       5.000000e+06
# 114       2.996566e+07
# 131       2.000000e+06
# 145       5.000000e+06
# 265       1.000000e+07
#               ...
# 139851    5.000000e+03
# 139852    6.000000e+03
# 139855    1.000000e+03
# 139857    1.850000e+05
# 139868    2.000000e+03
# 139870    7.000000e+02
# 139874    1.000000e+03
# 139881    4.440000e+04
# 139882    5.000000e+02
# 139884    5.000000e+02
# 139887    5.000000e+02
# 139889    5.350000e+05
# 139892    4.000000e+04
# 139896    9.000000e+02
# 139898    2.400000e+03
# 139902    5.000000e+02
# 139918    5.100000e+03
# 139919    9.000000e+02
# 139923    5.000000e+02
# 139927    1.000000e+05
# 139928    5.000000e+02
# 139937    1.000000e+03
# 139938    2.500000e+03
# 139955    8.000000e+02
# 139956    8.000000e+05
# 139958    5.000000e+02
# 139967    2.000000e+03
# 139972    1.800000e+03
# 139973    3.000000e+03
# 139982    9.000000e+02
# Name: current_price, Length: 22436, dtype: float64

# %%
# to be set in yaml
full = ["generation", "color", "fancy","fancy_type", "exclusive", 
            "cooldown", "purrs", "watches", "prestige", 
            "prestige_ranking", "fancy_ranking", "body", "mouth", 
            "eyes", "pattern", "colorprimary", "colorsecondary", 
            "colortertiary", "coloreyes", "current_price"]
# features_plus = ["generation", "color", "fancy","fancy_type", "exclusive", 
#             "cooldown", "purrs", "watches", "prestige", 
#             "prestige_ranking", "fancy_ranking", "body", "mouth", 
#             "eyes", "pattern", "colorprimary", "colorsecondary", 
#             "colortertiary", "coloreyes"]
features = ["generation", "fancy", "exclusive", "cooldown", "purrs", "watches", "prestige"]
# categoricals = ["color", "fancy_type", "fancy_ranking", "prestige_ranking", "body", 
#                 "mouth", "eyes", "pattern", "colorprimary", "colorsecondary", 
#                 "colortertiary", "coloreyes"]
target = ["current_price"]

# %%
#train = training.filter(items=full)
X = training.filter(items=feats)
y = training.filter(items=target)

# %%
y
# Out:
#         current_price
# 4        6.000000e+07
# 7        8.880000e+07
# 11       8.000000e+08
# 15       1.490000e+07
# 16       1.770000e+07
# 17       3.000000e+07
# 19       9.600000e+06
# 25       9.600000e+06
# 26       9.900000e+06
# 27       2.500000e+07
# 34       1.000000e+07
# 37       1.300000e+07
# 42       2.280000e+07
# 54       1.100000e+07
# 58       8.900000e+06
# 66       9.800000e+06
# 80       2.688595e+06
# 81       1.000000e+08
# 84       2.990000e+06
# 86       1.688000e+08
# 90       3.500000e+06
# 98       1.000000e+07
# 106      5.000000e+06
# 107      2.351135e+06
# 109      5.000000e+06
# 112      5.000000e+06
# 114      2.996566e+07
# 131      2.000000e+06
# 145      5.000000e+06
# 265      1.000000e+07
# ...               ...
# 139851   5.000000e+03
# 139852   6.000000e+03
# 139855   1.000000e+03
# 139857   1.850000e+05
# 139868   2.000000e+03
# 139870   7.000000e+02
# 139874   1.000000e+03
# 139881   4.440000e+04
# 139882   5.000000e+02
# 139884   5.000000e+02
# 139887   5.000000e+02
# 139889   5.350000e+05
# 139892   4.000000e+04
# 139896   9.000000e+02
# 139898   2.400000e+03
# 139902   5.000000e+02
# 139918   5.100000e+03
# 139919   9.000000e+02
# 139923   5.000000e+02
# 139927   1.000000e+05
# 139928   5.000000e+02
# 139937   1.000000e+03
# 139938   2.500000e+03
# 139955   8.000000e+02
# 139956   8.000000e+05
# 139958   5.000000e+02
# 139967   2.000000e+03
# 139972   1.800000e+03
# 139973   3.000000e+03
# 139982   9.000000e+02
#
# [22436 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import ensemble
# from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error, mean_absolute_error
# from sklearn import preprocessing

# %%
random_seed = 11
split = 0.9

# %%
X, y = shuffle(X, y, random_state=random_seed)
offset = int(X.shape[0] * split)
X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
params = {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

# %%
clf.fit(X_train, y_train)
# Out:
# c:\users\jd cook\anaconda3\envs\avc\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.01, loss='ls', max_depth=4,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
mae = mean_absolute_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mae)
# Out:
# MSE: 2431656211739.3247

# %%
import pickle
with open('../models/kitties_model.pkl', 'wb') as file:
    pickle.dump(clf, file)

# %%
with open(f'../models/kitties_model.pkl', 'rb') as f:
    clf = pickle.load(f)

# %%
pred = pd.read_sql("select * from kitties where id = " + str(3), engine)

# %%
X_pred = pred.filter(items=feats)

# %%
clf.predict(X_pred)
# Out:
# array([2.05681512e+12])

# %%
img = pd.read_sql("select image from kitties where id = " + str(3), engine)

# %%
img["image"][0]
# Out:
# 'https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/3.png'
